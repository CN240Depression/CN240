# %%
from datetime import datetime 
import os
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.base import BaseEstimator, TransformerMixin

# %%
condition_path = './CN240/data/condition/'
control_path = './CN240/data/control/'

# %%
import pandas as pd
df_score = pd.read_csv('./CN240/data/scores.csv')
df_score.describe
# Out:
# <bound method NDFrame.describe of           number  days  gender    age  afftype  melanch  inpatient    edu  \
# 0    condition_1    11       2  35-39      2.0      2.0        2.0   6-10
# 1    condition_2    18       2  40-44      1.0      2.0        2.0   6-10
# 2    condition_3    13       1  45-49      2.0      2.0        2.0   6-10
# 3    condition_4    13       2  25-29      2.0      2.0        2.0  11-15
# 4    condition_5    13       2  50-54      2.0      2.0        2.0  11-15
# 5    condition_6     7       1  35-39      2.0      2.0        2.0   6-10
# 6    condition_7    11       1  20-24      1.0      NaN        2.0  11-15
# 7    condition_8     5       2  25-29      2.0      NaN        2.0  11-15
# 8    condition_9    13       2  45-49      1.0      NaN        2.0   6-10
# 9   condition_10     9       2  45-49      2.0      2.0        2.0   6-10
# 10  condition_11    14       1  45-49      2.0      2.0        2.0   6-10
# ...

# %%
# df_legend = pd.read_csv('./CN240/facial_expressions/data/500_picts_satz.csv')
df_500 = pd.read_csv('./500_pict.csv')
df_500.groupby('emotion').count()
# Out:
#             id  name
# emotion
# anger      115   115
# fear        54    54
# happiness  197   197
# neutral     84    84
# sad         50    50

# %%
df_legend2 = pd.read_csv('./500_pict_2.csv')
df_legend2.loc[df_legend2['emotion'].str.isupper(), 'emotion'] = df_legend2['emotion'].str.lower()
df_legend2.groupby('emotion').count()
# Out:
#             id  name
# emotion
# anger      115   115
# fear        54    54
# happiness  197   197
# neutral     84    84
# sad         50    50

# %%
df_legend = pd.read_csv('./CN240/facial_expressions/data/legend.csv')
df_legend.loc[df_legend['emotion'].str.isupper(), 'emotion'] = df_legend['emotion'].str.lower()
df_legend.groupby('emotion').count()
# Out:
#            user.id  image
# emotion
# anger          252    252
# contempt         9      9
# disgust        208    208
# fear            21     21
# happiness     5696   5696
# neutral       6868   6868
# sadness        268    268
# surprise       368    368

# %% [markdown]
# ไม่มีข้อมูลซํ้ำ

# %%
df_500 = pd.read_csv('./CN240/facial_expressions/data/legend.csv')
column_names = ['user.id','image','emotion']
duplicates = df_500.duplicated(subset=column_names, keep=False)
df_500[duplicates]
# Out:
# Empty DataFrame
# Columns: [user.id, image, emotion]
# Index: []

# %% [markdown]
# loop check time stamp ซํ้า

# %%
# นึกไม่ออก
# # df_500 = pd.read_csv('./CN240/data/condition/')
# column_names = ['user.id','image','emotion']
# duplicates = df_500.duplicated(subset=column_names, keep=False)
# df_500[duplicates]

# %% [markdown]
# ข้างล่างของเบรฟ

# %%
import cv2 as cv
import csv

def load_filename_from_folder(folder):
    return [filename for filename in os.listdir(folder)]


def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv.imread(os.path.join(folder, filename))
        if img is not None:
            images.append(img)
    return images


def write(filename, data):
    csv_file = open(filename, "w", newline='')
    writer = csv.writer(csv_file, quoting=csv.QUOTE_NONNUMERIC, delimiter=",")
    for data in data:
        writer.writerow(data)
    csv_file.close()


def main():
    path = "Glaucoma"
    data = [["filename", "width", "height"]]
    filename = load_filename_from_folder(path)

    elem = 0
    for img in load_images_from_folder(path):
        width = img.shape[0]
        height = img.shape[1]
        data_for_append = [filename[elem], str(width), str(height)]
        data.append(data_for_append)
        elem += 1

    write("data.csv", data)


main()
